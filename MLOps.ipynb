# %%
import pandas as pd

# %%
df = pd.read_parquet('data/green_tripdata_2021-01.parquet')
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
# Calcualtae the trip duration for each trip
df['trip_duration'] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime)

# %%
#To be ble to use it on the model we need to convert the result to 
#a number, here we are going to convert them to minutes
df['duration'] = df['trip_duration'].apply(lambda x: x.total_seconds()/60)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  ...  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
import seaborn as sns

# %%
# Now lets see the distribution of duration column
sns.displot(df, x="duration", bins=100)
sns.set_style('darkgrid')

# %%
# Lets zoom in a little bit an see the details for durations shorter than 150 min
sns.displot(df[df.duration <150], x="duration", bins=100)
